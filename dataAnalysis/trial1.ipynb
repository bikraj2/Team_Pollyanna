# %%
import geopandas as gpd

# %%
buildings = gpd.read_file(r"SampleShapeFile/shape/buildings.shp")

# %%
roads = gpd.read_file(r"SampleShapeFile/shape/roads.shp")

# %%
roads
# Out:
#            osm_id           name   ref          type  oneway  bridge  \
# 0         4825621           None   F26       primary       0       0
# 1         4825630     Kanti Path  None       primary       1       0
# 2         4825671  Thabahi Sadak  None      tertiary       1       0
# 3         4839933           None  None  unclassified       1       0
# 4         4839936           None  None    trunk_link       1       0
# ...           ...            ...   ...           ...     ...     ...
# 49005  1066306215           None  None   residential       0       0
# 49006  1066354775           None  None   residential       0       0
# 49007  1066368753           None  None       service       0       0
# 49008  1066368754           None  None       service       0       0
# 49009  1066368756           None  None       service       0       0
#
#        maxspeed                                           geometry
# 0           NaN  LINESTRING (85.38651 27.72227, 85.38576 27.722...
# 1           NaN  LINESTRING (85.31422 27.70706, 85.31429 27.707...
# 2           NaN  LINESTRING (85.31242 27.71423, 85.31199 27.714...
# 3           NaN  LINESTRING (85.35589 27.70084, 85.35592 27.700...
# 4           NaN  LINESTRING (85.35371 27.70107, 85.35369 27.701...
# ...         ...                                                ...
# 49005       NaN  LINESTRING (85.34301 27.69820, 85.34285 27.697...
# 49006       NaN  LINESTRING (85.34268 27.69824, 85.34251 27.69779)
# 49007       NaN  LINESTRING (85.28768 27.66204, 85.28752 27.661...
# 49008       NaN  LINESTRING (85.32653 27.65498, 85.32678 27.654...
# 49009       NaN  LINESTRING (85.32611 27.65109, 85.32607 27.651...
#
# [49010 rows x 8 columns]

# %%
points = gpd.read_file(r"SampleShapeFile/shape/places.shp")

# %%
points
# Out:
#           osm_id              name           type  population  \
# 0       31151023        Gyaneshwar  neighbourhood         NaN
# 1       31230179            Jagati         suburb         NaN
# 2       67157058          काठमाडौं           city    975000.0
# 3      246543154    Dallu Chautara       locality         NaN
# 4      268301854         Bhedasing  neighbourhood         NaN
# ...          ...               ...            ...         ...
# 1482   938044945     medical chwok       locality         NaN
# 1483   939711339  Pabitra Workshop       locality         NaN
# 1484  1032926701   Pyangaun Bazaar        village         NaN
# 1485  1081913606        MiZu chowk       locality         NaN
# 1486  1153172899            Banasi         hamlet         NaN
#
#                        geometry
# 0     POINT (85.33055 27.70898)
# 1     POINT (85.43652 27.66654)
# 2     POINT (85.32058 27.70832)
# 3     POINT (85.29982 27.70963)
# 4     POINT (85.30976 27.70699)
# ...                         ...
# 1482  POINT (85.37406 27.69582)
# 1483  POINT (85.33087 27.72958)
# 1484  POINT (85.32531 27.59833)
# 1485  POINT (85.41059 27.71473)
# 1486  POINT (85.44579 27.67609)
#
# [1487 rows x 5 columns]

# %%
# hospitals= gpd
# for i in points:
    
#    if points.loc[i].type == "hospital":
#         hopsitals.append(points[i])
# hospitals
points.loc[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [18], in <cell line: 2>()
#       1 hospitals= gpd
#       2 for i in points:
# ----> 4    if points.loc[i].type == "hospital":
#       5         hopsitals.append(points[i])
#       6         print('asdf')
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1202, in _LocIndexer._getitem_axis(self, key, axis)
#    1200 # fall thru to straight lookup
#    1201 self._validate_key(key, axis)
# -> 1202 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1153, in _LocIndexer._get_label(self, label, axis)
#    1151 def _get_label(self, label, axis: int):
#    1152     # GH#5667 this will fail if the label is not present in the axis.
# -> 1153     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:3864, in NDFrame.xs(self, key, axis, level, drop_level)
#    3862             new_index = index[loc]
#    3863 else:
# -> 3864     loc = index.get_loc(key)
#    3866     if isinstance(loc, np.ndarray):
#    3867         if loc.dtype == np.bool_:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'osm_id'

# %%
hospitals=points[points.type=='city']

# %%
hospitals
# Out:
# Empty GeoDataFrame
# Columns: [osm_id, name, type, population, geometry]
# Index: []
